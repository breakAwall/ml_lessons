# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 

import boto3
import sagemaker
from sagemaker import get_execution_role

import sklearn.model_selection

# %matplotlib inline

# %% [markdown]
# ### Evaluation
# Before doing anything else, we want to create a method to evaluate our models performance. This method should give back us evaluation metrics such as recall, f1, precision, and accuracy. Since we are doing binary prediction I will be using the code used for fraud detection but modifying it a little bit (including f1 score)

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    f1 = tp / (tp + 0.5*(fp + fn))
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print("{:<11} {:.3f}".format('F1:', f1))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %% [markdown]
# ### Data setup
# To set up the sagemaker environment we are going to have to get our sessions, role, bucket, and data. We will also define the helper to delete an endpoint here

# %%
# sagemaker session, role, region
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %%
X_test = pd.read_csv("data/X_test.csv", index_col=0)
Y_test = pd.read_csv("data/Y_test.csv", index_col=0)
X_train = pd.read_csv("data/X_train.csv", index_col=0)
Y_train = pd.read_csv("data/Y_train.csv", index_col=0)

# %%
X_train
# Out:
#        reward  difficulty  duration  mobile  social  web  bogo  discount  \
# 20763      10          10         7       1       1    0     1         0
# 35564       5          20        10       0       0    1     0         1
# 21422       2          10         7       1       0    1     0         1
# 44277       0           0         4       1       0    1     0         0
# 33385       2          10        10       1       1    1     0         1
# ...       ...         ...       ...     ...     ...  ...   ...       ...
# 2324        5           5         7       1       0    1     1         0
# 37366       0           0         3       1       1    0     0         0
# 9707        2          10        10       1       1    1     0         1
# 17014      10          10         5       1       1    1     1         0
# 3235        5           5         5       1       1    1     1         0
#
#        informational  age   income  F  M  O  days_since_member
# 20763              0   78  64000.0  0  1  0                407
# 35564              0   47  80000.0  1  0  0               1274
# 21422              0   77  83000.0  1  0  0               1569
# 44277              1   52  88000.0  0  1  0               1575
# 33385              0   63  70000.0  1  0  0               1354
# ...              ...  ...      ... .. .. ..                ...
# 2324               0   53  56000.0  0  1  0               1765
# 37366              1   40  56000.0  0  1  0               1504
# 9707               0   50  84000.0  0  1  0                417
# 17014              0   23  36000.0  0  1  0               1039
# 3235               0   35  38000.0  1  0  0               1763
#
# [13659 rows x 15 columns]

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %% [markdown]
# ### Linear Learner
# We will first be using linear learner, we will try using linear learner raw first and then see how we do if we optimize it for recall. While we want a high f1 score, as that's our primary metric. It is probably more valuable for starbucks to get all potential customers and miss a few, than send promotions to those who would not use them.

# %%
# import LinearLearner
from sagemaker import LinearLearner

# specify an output path
prefix = 'promotion_success'
output_path = 's3://{}/{}'.format(bucket, prefix)

# instantiate LinearLearner, no recall optimization
linear = LinearLearner(role=role,
                       instance_count=1, 
                       instance_type='ml.c4.xlarge',
                       predictor_type='binary_classifier',
                       output_path=output_path,
                       sagemaker_session=sagemaker_session,
                       epochs=15)

# %%
# convert features/labels to numpy
X_train_np = X_train.astype('float32').values
Y_train_np = Y_train['Y'].astype('float32').values
X_test_np = X_test.astype('float32').values
Y_test_np = Y_test['Y'].astype('float32').values

# create RecordSet
formatted_train_data = linear.record_set(X_train_np, labels=Y_train_np)

# %%
# %%time 
# train the estimator on formatted training data
linear.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-03-13 04:29:56 Starting - Starting the training job...
# 2021-03-13 04:30:21 Starting - Launching requested ML instancesProfilerReport-1615609796: InProgress
# ......
# 2021-03-13 04:31:21 Starting - Preparing the instances for training.........
# 2021-03-13 04:32:54 Downloading - Downloading input data
# 2021-03-13 04:32:54 Training - Downloading the training image...
# 2021-03-13 04:33:23 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [03/13/2021 04:33:22 INFO 139684215854912] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/13/2021 04:33:22 INFO 139684215854912] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'15', u'feature_dim': u'15', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier'}
# [03/13/2021 04:33:22 INFO 139684215854912] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03
"Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615610007.062407}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6940225219726562, "sum": 0.6940225219726562, "min": 0.6940225219726562}}, "EndTime": 1615610007.062499, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615610007.062479}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6940977548452524, "sum": 0.6940977548452524, "min": 0.6940977548452524}}, "EndTime": 1615610007.062564, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615610007.062548}
#
# [03/13/2021 04:33:27 INFO 139684215854912] #quality_metric: host=algo-1, epoch=8, train binary_classification_cross_entropy_objective <loss>=0.667530015212
# [03/13/2021 04:33:27 INFO 139684215854912] #early_stopping_criteria_metric: host=algo-1, epoch=8, criteria=binary_classification_cross_entropy_objective, value=0.667336782602
# [03/13/2021 04:33:27 INFO 139684215854912] Saving model for epoch: 8
# [03/13/2021 04:33:27 INFO 139684215854912] Saved checkpoint to "/tmp/tmpbgS6NC/mx-mod-0000.params"
# [03/13/2021 04:33:27 INFO 139684215854912] Early stop condition met. Stopping training.
# [03/13/2021 04:33:27 INFO 139684215854912] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 14, "sum": 14.0, "min": 14}, "Number of Batches Since Last Reset": {"count": 1, "max": 14, "sum": 14.0, "min": 14}, "Number of Records Since Last Reset": {"count": 1, "max": 13659, "sum": 13659.0, "min": 13659}, "Total Batches Seen": {"count": 1, "max": 138, "sum": 138.0, "min": 138}, "Total Records Seen": {"count": 1, "max": 134931, "sum": 134931.0, "min": 134931}, "Max Records Seen Between Resets": {"count": 1, "max": 13659, "sum": 13659.0, "min": 13659}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1615610007.06932, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615610006.571049}
#
# [03/13/2021 04:33:27 INFO 139684215854912] #throughput_metric: host=algo-1, train throughput=27405.9225956 records/second
# [03/13/2021 04:33:27 WARNING 139684215854912] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/13/2021 04:33:27 WARNING 139684215854912] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-03-13 04:33:27.074] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 21, "duration": 4, "num_examples": 1, "num_bytes": 104000}
# [2021-03-13 04:33:27.220] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 24, "duration": 144, "num_examples": 14, "num_bytes": 1420536}
# [2021-03-13 04:33:27.284] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 49, "num_examples": 14, "num_bytes": 1420536}
# [03/13/2021 04:33:27 INFO 139684215854912] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.6675346000833928)
# [03/13/2021 04:33:27 INFO 139684215854912] #train_score (algo-1) : ('binary_classification_accuracy', 0.605608024013471)
# [03/13/2021 04:33:27 INFO 139684215854912] #train_score (algo-1) : ('binary_f_1.000', 0.6262920568851891)
# [03/13/2021 04:33:27 INFO 139684215854912] #train_score (algo-1) : ('precision', 0.594651561059149)
# [03/13/2021 04:33:27 INFO 139684215854912] #train_score (algo-1) : ('recall', 0.6614888628370457)
# [03/13/2021 04:33:27 INFO 139684215854912] #train_score (algo-1) : ('roc_auc_score', 0.6272622402450665)
# [03/13/2021 04:33:27 INFO 139684215854912] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.667534600083
# [03/13/2021 04:33:27 INFO 139684215854912] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.605608024013
# [03/13/2021 04:33:27 INFO 139684215854912] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.626292056885
# [03/13/2021 04:33:27 INFO 139684215854912] #quality_metric: host=algo-1, train precision <score>=0.594651561059
# [03/13/2021 04:33:27 INFO 139684215854912] #quality_metric: host=algo-1, train recall <score>=0.661488862837
# [03/13/2021 04:33:27 INFO 139684215854912] #quality_metric: host=algo-1, train roc_auc_score <score>=0.627262240245
# [03/13/2021 04:33:27 INFO 139684215854912] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [03/13/2021 04:33:27 INFO 139684215854912] Saved checkpoint to "/tmp/tmplpLINu/mx-mod-0000.params"
# [03/13/2021 04:33:27 INFO 139684215854912] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 4978.979110717773, "sum": 4978.979110717773, "min": 4978.979110717773}, "finalize.time": {"count": 1, "max": 223.2649326324463, "sum": 223.2649326324463, "min": 223.2649326324463}, "initialize.time": {"count": 1, "max": 217.33808517456055, "sum": 217.33808517456055, "min": 217.33808517456055}, "check_early_stopping.time": {"count": 9, "max": 1.3058185577392578, "sum": 5.757808685302734, "min": 0.20194053649902344}, "setuptime": {"count": 1, "max": 45.526981353759766, "sum": 45.526981353759766, "min": 45.526981353759766}, "update.time": {"count": 9, "max": 565.6170845031738, "sum": 4202.904939651489, "min": 428.2341003417969}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1615610007.298474, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1615610002.609821}
# 2021-03-13 04:33:43 Uploading - Uploading generated training model
# 2021-03-13 04:33:43 Completed - Training job completed
# Training seconds: 58
# Billable seconds: 58
# CPU times: user 655 ms, sys: 45.8 ms, total: 701 ms
# Wall time: 4min 14s

# %%
# %%time 
# deploy and create a predictor
linear_predictor = linear.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ---------------------!CPU times: user 356 ms, sys: 21.2 ms, total: 378 ms
# Wall time: 10min 33s

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   X_test_np, 
                   Y_test_np, 
                   verbose=True)
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)   0.0   1.0
# actual (row)
# 0.0               1817  1542
# 1.0               1162  2208
#
# Recall:     0.655
# Precision:  0.589
# Accuracy:   0.598
# F1:         0.620

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2021-03-13-04-36-11-963

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-03-13 04:49:07 Starting - Starting the training job...
# 2021-03-13 04:49:31 Starting - Launching requested ML instancesProfilerReport-1615610947: InProgress
# ......
# 2021-03-13 04:50:32 Starting - Preparing the instances for training.........
# 2021-03-13 04:52:05 Downloading - Downloading input data
# 2021-03-13 04:52:05 Training - Downloading the training image...
# 2021-03-13 04:52:36 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [03/13/2021 04:52:29 INFO 140250816034624] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/13/2021 04:52:29 INFO 140250816034624] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'feature_dim': u'15', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [03/13/2021 04:52:29 INFO 140250816034624] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [03/13/2021 04:52:29 WARNING 140250816034624] Loggers have already been setup.
# Process 1 is a worker.
# [03/13/2021 04:52:29 INFO 140250816034624] Using default worker.
# [03/13/2021 04:52:29 INFO 140250816034624] Checkpoint loading and saving are disabled.
# [2021-03-13 04:52:29.763] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 21, "num_examples": 1, "num_bytes": 104000}
# [03/13/2021 04:52:29 INFO 140250816034624] Create Store: local
# [2021-03-13 04:52:29.862] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 97, "num_examples": 11, "num_bytes": 1144000}
# [03/13/2021 04:52:29 INFO 140250816034624] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f8e50955e90>
# [03/13/2021 04:52:29 INFO 140250816034624] Scaling model computed with parameters:
#  {'stdev_weight':
# [3.44997215e+00 5.17907667e+00 2.17225194e+00 2.77114987e-01
#  4.74075854e-01 4.03967142e-01 4.94287699e-01 4.89972055e-01
#  3.79967153e-01 1.71916237e+01 2.15580898e+04 4.92516667e-01
#  4.94802058e-01 1.18612885e-01 4.19592285e+02]
# <NDArray 15 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [4.4112730e+00 7.7390914e+00 6.5363631e+00 9.1618186e-01 6.5890914e-01
#  7.9463643e-01 4.2463636e-01 4.0036362e-01 1.7500001e-01 5.4162544e+01
#  6.5320277e+04 4.1381818e-01 5.7190913e-01 1.4272729e-02 1.3010056e+03]
# <NDArray 15 @cpu(0)>}
# [03/13/2021 04:52:29 INFO 140250816034624] nvidia-smi took: 0.0251770019531 secs to identify 0 gpus
# [03/13/2021 04:52:29 INFO 140250816034624] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1615611149.965345, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1615611149.965308}
#
# [2021-03-13 04:52:30.369] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 403, "num_examples": 14, "num_bytes": 1420536}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6833365994966947, "sum": 0.6833365994966947, "min": 0.6833365994966947}}, "EndTime": 1615611150.369221, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1615611150
#early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.670182988093
# [03/13/2021 04:52:31 INFO 140250816034624] Epoch 2: Loss improved. Updating best model
# [03/13/2021 04:52:31 INFO 140250816034624] Saving model for epoch: 2
# [03/13/2021 04:52:31 INFO 140250816034624] Saved checkpoint to "/tmp/tmpJKLQ8z/mx-mod-0000.params"
# [03/13/2021 04:52:31 INFO 140250816034624] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 14, "sum": 14.0, "min": 14}, "Number of Batches Since Last Reset": {"count": 1, "max": 14, "sum": 14.0, "min": 14}, "Number of Records Since Last Reset": {"count": 1, "max": 13659, "sum": 13659.0, "min": 13659}, "Total Batches Seen": {"count": 1, "max": 54, "sum": 54.0, "min": 54}, "Total Records Seen": {"count": 1, "max": 52977, "sum": 52977.0, "min": 52977}, "Max Records Seen Between Resets": {"count": 1, "max": 13659, "sum": 13659.0, "min": 13659}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1615611151.252422, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1615611150.77979}
#
# [03/13/2021 04:52:31 INFO 140250816034624] #throughput_metric: host=algo-1, train throughput=28893.0168244 records/second
# [2021-03-13 04:52:31.853] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 600, "num_examples": 14, "num_bytes": 1420536}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6695529080904448, "sum": 0.6695529080904448, "min": 0.6695529080904448}}, "EndTime": 1615611151.853763, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1615611151.853372}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6687686861478366, "sum": 0.6687686861478366, "min": 0.6687686861478366}}, "EndTime": 1615611151.853878, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1615611151.853855}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6702796583909255, "sum": 0.6702796583909255, "min": 0.6702796583909255}}, "EndTime": 1615611151.854052, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1615611151.85393}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6698067063551683, "sum": 0.6698067063551683, "min": 0.6698067063551683}}, "EndTime": 1615611151.854258, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1615611151.854234}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6732203650841346, "sum": 0.6732203650841346, "min": 0.6732203650841346}}, "EndTime": 1615611151.854421, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1615611151.854398}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.673532968374399, "sum": 0.673532968374399, "min": 0.673532968374399}}, "EndTime": 1615611151.854491, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1615611151.854474}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6739520920973557, "sum": 0.6739520920973557, "min": 0.6739520920973557}}, "EndTime": 1615611151.85455, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1615611151.854535}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6677794189453125, "sum": 0.6677794189453125, "min": 0.6677794189453125}}, "EndTime": 1615611154.125144, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125132}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6675293813852163, "sum": 0.6675293813852163, "min": 0.6675293813852163}}, "EndTime": 1615611154.125207, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125189}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6708196645883413, "sum": 0.6708196645883413, "min": 0.6708196645883413}}, "EndTime": 1615611154.125268, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125251}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6714171095628004, "sum": 0.6714171095628004, "min": 0.6714171095628004}}, "EndTime": 1615611154.125332, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125313}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6709582801231971, "sum": 0.6709582801231971, "min": 0.6709582801231971}}, "EndTime": 1615611154.125393, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125376}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6709823843149039, "sum": 0.6709823843149039, "min": 0.6709823843149039}}, "EndTime": 1615611154.125455, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125438}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6678265005258414, "sum": 0.6678265005258414, "min": 0.6678265005258414}}, "EndTime": 1615611154.125517, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.1255}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6678645301231971, "sum": 0.6678645301231971, "min": 0.6678645301231971}}, "EndTime": 1615611154.125594, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125566}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6677368727463943, "sum": 0.6677368727463943, "min": 0.6677368727463943}}, "EndTime": 1615611154.125657, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125638}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6674364999624399, "sum": 0.6674364999624399, "min": 0.6674364999624399}}, "EndTime": 1615611154.125714, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125698}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6707417602539063, "sum": 0.6707417602539063, "min": 0.6707417602539063}}, "EndTime": 1615611154.125774, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125757}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6710697397085337, "sum": 0.6710697397085337, "min": 0.6710697397085337}}, "EndTime": 1615611154.125835, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125817}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6706829693134014, "sum": 0.6706829693134014, "min": 0.6706829693134014}}, "EndTime": 1615611154.125894, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125877}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6711305635892428, "sum": 0.6711305635892428, "min": 0.6711305635892428}}, "EndTime": 1615611154.125955, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125938}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6820616220327524, "sum": 0.6820616220327524, "min": 0.6820616220327524}}, "EndTime": 1615611154.126014, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.125998}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6820789794921875, "sum": 0.6820789794921875, "min": 0.6820789794921875}}, "EndTime": 1615611154.126073, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126056}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6820509267953726, "sum": 0.6820509267953726, "min": 0.6820509267953726}}, "EndTime": 1615611154.126135, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126118}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6820702749399038, "sum": 0.6820702749399038, "min": 0.6820702749399038}}, "EndTime": 1615611154.126192, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126177}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6829125131460336, "sum": 0.6829125131460336, "min": 0.6829125131460336}}, "EndTime": 1615611154.126246, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126235}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6832537794846755, "sum": 0.6832537794846755, "min": 0.6832537794846755}}, "EndTime": 1615611154.1263, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126284}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6830974778395432, "sum": 0.6830974778395432, "min": 0.6830974778395432}}, "EndTime": 1615611154.126367, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126349}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.683160888671875, "sum": 0.683160888671875, "min": 0.683160888671875}}, "EndTime": 1615611154.126427, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126411}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6931224975585938, "sum": 0.6931224975585938, "min": 0.6931224975585938}}, "EndTime": 1615611154.126479, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126463}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6931301973783053, "sum": 0.6931301973783053, "min": 0.6931301973783053}}, "EndTime": 1615611154.126538, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.12652}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6930980834960937, "sum": 0.6930980834960937, "min": 0.6930980834960937}}, "EndTime": 1615611154.126609, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126591}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6931302771935096, "sum": 0.6931302771935096, "min": 0.6931302771935096}}, "EndTime": 1615611154.126681, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126662}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6940284611628605, "sum": 0.6940284611628605, "min": 0.6940284611628605}}, "EndTime": 1615611154.126752, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126734}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6940855900691105, "sum": 0.6940855900691105, "min": 0.6940855900691105}}, "EndTime": 1615611154.126822, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126804}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6940225219726562, "sum": 0.6940225219726562, "min": 0.6940225219726562}}, "EndTime": 1615611154.126882, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126866}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6940977548452524, "sum": 0.6940977548452524, "min": 0.6940977548452524}}, "EndTime": 1615611154.126939, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611154.126925}
#
# [03/13/2021 04:52:34 INFO 140250816034624] #quality_metric: host=algo-1, epoch=8, train binary_classification_cross_entropy_objective <loss>=0.667530015212
# [03/13/2021 04:52:34 INFO 140250816034624] #early_stopping_criteria_metric: host=algo-1, epoch=8, criteria=binary_classification_cross_entropy_objective, value=0.667336782602
# [03/13/2021 04:52:34 INFO 140250816034624] Saving model for epoch: 8
# [03/13/2021 04:52:34 INFO 140250816034624] Saved checkpoint to "/tmp/tmpdZga5Q/mx-mod-0000.params"
# [03/13/2021 04:52:34 INFO 140250816034624] Early stop condition met. Stopping training.
# [03/13/2021 04:52:34 INFO 140250816034624] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 14, "sum": 14.0, "min": 14}, "Number of Batches Since Last Reset": {"count": 1, "max": 14, "sum": 14.0, "min": 14}, "Number of Records Since Last Reset": {"count": 1, "max": 13659, "sum": 13659.0, "min": 13659}, "Total Batches Seen": {"count": 1, "max": 138, "sum": 138.0, "min": 138}, "Total Records Seen": {"count": 1, "max": 134931, "sum": 134931.0, "min": 134931}, "Max Records Seen Between Resets": {"count": 1, "max": 13659, "sum": 13659.0, "min": 13659}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1615611154.133451, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1615611153.713074}
#
# [03/13/2021 04:52:34 INFO 140250816034624] #throughput_metric: host=algo-1, train throughput=32483.6948381 records/second
# [03/13/2021 04:52:34 WARNING 140250816034624] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/13/2021 04:52:34 WARNING 140250816034624] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-03-13 04:52:34.138] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 21, "duration": 4, "num_examples": 1, "num_bytes": 104000}
# [2021-03-13 04:52:34.263] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 24, "duration": 122, "num_examples": 14, "num_bytes": 1420536}
# [2021-03-13 04:52:34.328] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 49, "num_examples": 14, "num_bytes": 1420536}
# [03/13/2021 04:52:34 INFO 140250816034624] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.6675346000833928)
# [03/13/2021 04:52:34 INFO 140250816034624] #train_score (algo-1) : ('binary_classification_accuracy', 0.5552383044146716)
# [03/13/2021 04:52:34 INFO 140250816034624] #train_score (algo-1) : ('binary_f_1.000', 0.6691717039699395)
# [03/13/2021 04:52:34 INFO 140250816034624] #train_score (algo-1) : ('precision', 0.5324551520929023)
# [03/13/2021 04:52:34 INFO 140250816034624] #train_score (algo-1) : ('recall', 0.9003516998827668)
# [03/13/2021 04:52:34 INFO 140250816034624] #train_score (algo-1) : ('roc_auc_score', 0.6272622402450665)
# [03/13/2021 04:52:34 INFO 140250816034624] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.667534600083
# [03/13/2021 04:52:34 INFO 140250816034624] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.555238304415
# [03/13/2021 04:52:34 INFO 140250816034624] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.66917170397
# [03/13/2021 04:52:34 INFO 140250816034624] #quality_metric: host=algo-1, train precision <score>=0.532455152093
# [03/13/2021 04:52:34 INFO 140250816034624] #quality_metric: host=algo-1, train recall <score>=0.900351699883
# [03/13/2021 04:52:34 INFO 140250816034624] #quality_metric: host=algo-1, train roc_auc_score <score>=0.627262240245
# [03/13/2021 04:52:34 INFO 140250816034624] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [03/13/2021 04:52:34 INFO 140250816034624] Saved checkpoint to "/tmp/tmpaKQItv/mx-mod-0000.params"
# [03/13/2021 04:52:34 INFO 140250816034624] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 4839.9012088775635, "sum": 4839.9012088775635, "min": 4839.9012088775635}, "finalize.time": {"count": 1, "max": 202.41189002990723, "sum": 202.41189002990723, "min": 202.41189002990723}, "initialize.time": {"count": 1, "max": 218.57595443725586, "sum": 218.57595443725586, "min": 218.57595443725586}, "check_early_stopping.time": {"count": 9, "max": 0.9939670562744141, "sum": 5.173444747924805, "min": 0.19693374633789062}, "setuptime": {"count": 1, "max": 25.567054748535156, "sum": 25.567054748535156, "min": 25.567054748535156}, "update.time": {"count": 9, "max": 607.9349517822266, "sum": 4138.770341873169, "min": 366.27912521362305}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1615611154.34107, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1615611149.72924}
# 2021-03-13 04:52:53 Completed - Training job completed
# Training seconds: 46
# Billable seconds: 46
# CPU times: user 580 ms, sys: 40.5 ms, total: 621 ms
# Wall time: 4min 12s

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------------------!CPU times: user 419 ms, sys: 17.2 ms, total: 436 ms
# Wall time: 12min 33s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

metrics = evaluate(recall_predictor, 
                   X_test_np, 
                   Y_test_np, 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
#
# prediction (col)  0.0   1.0
# actual (row)
# 0.0               661  2698
# 1.0               333  3037
#
# Recall:     0.901
# Precision:  0.530
# Accuracy:   0.550
# F1:         0.667

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2021-03-13-04-53-33-198

# %% [markdown]
# ### Set up XGBoost hyperparmeter tunning

# %%
X_train, X_val, Y_train, Y_val = sklearn.model_selection.train_test_split(X_train, Y_train, test_size=0.33)

# %%
prefix = 'promotion_success/xgboost'
data_dir = 'data/sm'

X_test.to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

pd.concat([Y_val, X_val], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([Y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

test_location = sagemaker_session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = sagemaker_session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = sagemaker_session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %%
from sagemaker.image_uris import retrieve
from sagemaker.xgboost.estimator import XGBoost

container = retrieve('xgboost', region, version='1.0-1')

xgb = sagemaker.estimator.Estimator(container, 
                                    role,     
                                    instance_count=1, 
                                    instance_type='ml.m4.xlarge', 
                                    output_path=output_path,
                                    sagemaker_session=sagemaker_session)

xgb.set_hyperparameters(max_depth=4,
                        eta=0.2,
                        min_child_weight=6,
                        objective='reg:logistic',
                        early_stopping_rounds=10,
                        num_round=200)

# %%
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner
from sagemaker.xgboost.estimator import XGBoost


xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb,
                                               objective_metric_name = 'validation:f1', 
                                               objective_type = 'Maximize', 
                                               max_jobs = 20, 
                                               max_parallel_jobs = 3,
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 8),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'alpha'    : ContinuousParameter(0, 2),
                                                    'min_child_weight': IntegerParameter(1, 10),
                                               })

# %%
s3_input_train = sagemaker.inputs.TrainingInput(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.inputs.TrainingInput(s3_data=val_location, content_type='csv')

xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})
xgb_hyperparameter_tuner.wait()
# Out:
# ......................................................................................................................................................................................................................................................................................................................................................................!
# !

# %%
xgb_hyperparameter_tuner.best_training_job()
# Out:
# 'sagemaker-xgboost-210313-1923-019-bc44ea89'

# %%
xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2021-03-13 19:53:08 Starting - Preparing the instances for training
# 2021-03-13 19:53:08 Downloading - Downloading input data
# 2021-03-13 19:53:08 Training - Training image download completed. Training in progress.
# 2021-03-13 19:53:08 Uploading - Uploading generated training model
# 2021-03-13 19:53:08 Completed - Training job completed

# %%
xgb_predictor = xgb_attached.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# -----------------------!

# %%
from sagemaker.serializers import CSVSerializer
xgb_predictor.serializer = CSVSerializer()

# %%
def evalution_metrics_xgb(test_labels, test_preds, verbose=True):
        
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    f1 = tp / (tp + 0.5*(fp + fn))
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print("{:<11} {:.3f}".format('F1:', f1))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %%
test_preds = str(xgb_predictor.predict(X_test.to_csv(header=False, index=False))).split(',')
test_preds[0] = test_preds[0][2:]
test_preds[-1] = test_preds[-1][:-2]

# %%
test_preds = [round(float(x)) for x in test_preds]
_ = evalution_metrics_xgb(Y_test_np, np.asarray(test_preds))
# Out:
# prediction (col)     0     1
# actual (row)
# 0.0               1789  1570
# 1.0               1143  2227
#
# Recall:     0.661
# Precision:  0.587
# Accuracy:   0.597
# F1:         0.621

# %%
delete_endpoint(xgb_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted sagemaker-xgboost-2021-03-13-19-55-26-382
